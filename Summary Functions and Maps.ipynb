# %%
# Quick Overview

# describe()
# mean()
# unique()
# value_counts() - unique values and how often they occur

# Maps
# A fucntion that takes one set of values and maps them to another set of values.
#2 methods
# map()
## returns a Series

# apply()
## returns a dataframe
## equivalent method to transform a whole DF by calling a custom method on each row.
## axis='columns' means transformation is applied to each row.
## axis='index' means transformation is applied to each column.

#map() and apply() do not modify the original data. They return transformed Series and DataFrames respectively.

# pandas provides common mapping operations as built-ins. These are faster as they use speed ups built into pandas.

# %%
import pandas as pd

#read housing dataset
X = pd.read_csv("train.csv", index_col='Id')

X.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#remean SalePrice to 0 using map()

SalePrice_mean = X.SalePrice.mean()
SalePrice_mean
X.SalePrice.map(lambda p: p - SalePrice_mean)
# Out:
# Id
# 1       27578.80411
# 2         578.80411
# 3       42578.80411
# 4      -40921.19589
# 5       69078.80411
#            ...
# 1456    -5921.19589
# 1457    29078.80411
# 1458    85578.80411
# 1459   -38796.19589
# 1460   -33421.19589
# Name: SalePrice, Length: 1460, dtype: float64

# %%
# using the apply() method to remean SalePrice to 0

def remean_price(row):
    row.SalePrice = row.SalePrice - SalePrice_mean
    return row
X.apply(remean_price, axis='columns')
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Better way to calculate mean without using map() and apply()
# pandas understands we are subtracting a constant value from a series of prices

SalePrice_mean = X.SalePrice.mean()
X.SalePrice - SalePrice_mean

# %%
X.SalePrice
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# pandas also understands we want to concatenate two series
#X.MSZoning + "-" + X.LotShape
X.MSZoning + "-" + X.MSSubClass.astype(str)
# Out:
# Id
# 1       RL-60
# 2       RL-20
# 3       RL-60
# 4       RL-70
# 5       RL-60
#         ...
# 1456    RL-60
# 1457    RL-20
# 1458    RL-70
# 1459    RL-20
# 1460    RL-20
# Length: 1460, dtype: object

# %%
X.MSZoning.value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
# 'best' house deal
# either get max of area/sales or min of sales/area
bargain_area_idx = (X.LotArea/X.SalePrice).idxmax()
bargain_area_idx

X.loc[bargain_area_idx, ['LotArea','SalePrice']].to_frame().transpose()
# Out:
#     LotArea SalePrice
# 336  164660    228950

# %%
X.LotConfig.value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64

# %%
# finding text in a string

side_in_lotconfig = X.LotConfig.map(lambda x: 'side' in x)
side_in_lotconfig
# Out:
# Id
# 1        True
# 2       False
# 3        True
# 4       False
# 5       False
#         ...
# 1456     True
# 1457     True
# 1458     True
# 1459     True
# 1460     True
# Name: LotConfig, Length: 1460, dtype: bool

# %%
#checking that count matches for 'Inside'
side_in_lotconfig.sum()
# Out:
# 1052

# %%
pav_in_street = X.Street.map(lambda x: 'Pav' in x)
pav_in_street.sum()

text_match_counts = pd.Series([side_in_lotconfig.sum(), pav_in_street.sum()], index=['side','pav'])
text_match_counts
# Out:
# side    1052
# pav     1454
# dtype: int64

# %%
# Divide SalePrice into 3 categories - 'inexpensive', 'fair value', 'expensive'

#X.SalePrice.describe()
SalePrice_25qtle = X.SalePrice.quantile(0.25)
SalePrice_75qtle = X.SalePrice.quantile(0.75)

def price_to_cat(row):
    if row.SalePrice <= SalePrice_25qtle:
        return 'inexpensive'
    elif row.SalePrice >= SalePrice_75qtle:
        return 'expensive'
    else:
        return 'fair value'
    
price_cat = X.apply(price_to_cat, axis='columns')
price_cat
# Out:
# Id
# 1       fair value
# 2       fair value
# 3        expensive
# 4       fair value
# 5        expensive
#            ...
# 1456    fair value
# 1457    fair value
# 1458     expensive
# 1459    fair value
# 1460    fair value
# Length: 1460, dtype: object

# %%
#X_train = X.assign(price_cat = price_cat)
# axis number -> 0 = rows, 1 = columns
#X_train.drop('price_cat', axis=1, inplace=True)

# %%
# create a new column with the ratio of prict to area.
# Use this ratio to divide houses into 3 categories - inexpensive, fair value and expensive ( in the next cell)
X_train = X.assign(price_to_area = X.SalePrice/X.LotArea)
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# Id                                    ...
# ...

# %%
X_train.price_to_area.idxmin()
# Out:
# 336

# %%
# Divide price_to_area into 3 categories - 'inexpensive', 'fair value', 'expensive'

#X.SalePrice.describe()
p2a_25qtle = X_train.price_to_area.quantile(0.25)
p2a_75qtle = X_train.price_to_area.quantile(0.75)

def p2a_to_cat(row):
    if row.price_to_area <= p2a_25qtle:
        return 'bargain'
    elif row.price_to_area >= p2a_75qtle:
        return 'money_printer_go_brr'
    else:
        return 'fair_value'
    
bargain_cat = X_train.apply(p2a_to_cat, axis='columns')
bargain_cat.value_counts()
# Out:
# fair_value              730
# money_printer_go_brr    365
# bargain                 365
# dtype: int64

# %%
X_train.price_to_area.describe()
# Out:
# count    1460.000000
# mean       21.069878
# std        12.387559
# min         1.390441
# 25%        13.775136
# 50%        17.856628
# 75%        23.769031
# max        95.384615
# Name: price_to_area, dtype: float64

# %%
X_train = X_train.assign(bargain_cat = bargain_cat)
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ...  Fence MiscFeature MiscVal MoSold  \
# Id                                    ...
# ...

# %%
#X_train.drop('bargain_cat', axis=1, inplace=True)

# %%
# apartmrents which are a bargain, have at least 20000 sqft lot area, LotShape Regular

X_train.loc[(X_train.bargain_cat == 'bargain') & (X_train.LotArea >= 20000) & (X_train.LotShape == 'Reg')].sort_values(by='SalePrice')
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1384          30       RL          NaN    25339   Pave   NaN      Reg
# 423           20       RL        100.0    21750   Pave   NaN      Reg
# 1049          20       RL        100.0    21750   Pave   NaN      Reg
# 877           20       RL         94.0    25286   Pave   NaN      Reg
# 1011          50       RL        115.0    21286   Pave   NaN      Reg
# 944           90       RL        100.0    25000   Pave   NaN      Reg
# 412          190       RL        100.0    34650   Pave   NaN      Reg
# 1191         190       RL          NaN    32463   Pave   NaN      Reg
# 564           50       RL         66.0    21780   Pave   NaN      Reg
# 1185          20       RL         50.0    35133   Grvl   NaN      Reg
# 114           20       RL          NaN    21000   Pave   NaN      Reg
# 808           70       RL        144.0    21384   Pave   NaN      Reg
# ...
